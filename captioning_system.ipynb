# %%
import os
import pandas as pd
from transformers import VisionEncoderDecoderModel, ViTFeatureExtractor, AutoTokenizer
from PIL import Image

# %% [markdown]
# # MÉTODO DE CAPTIONING 1 - VIT IMAGE CAPTIONING

# %%
model_name = "nlpconnect/vit-gpt2-image-captioning"
model = VisionEncoderDecoderModel.from_pretrained(model_name)
feature_extractor = ViTFeatureExtractor.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/4.61k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/982M [00:00<?, ?B/s]
# Config of the encoder: <class 'transformers.models.vit.modeling_vit.ViTModel'> is overwritten by shared encoder config: ViTConfig {
#   "architectures": [
#     "ViTModel"
#   ],
#   "attention_probs_dropout_prob": 0.0,
#   "encoder_stride": 16,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.0,
#   "hidden_size": 768,
#   "image_size": 224,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "model_type": "vit",
#   "num_attention_heads": 12,
#   "num_channels": 3,
#   "num_hidden_layers": 12,
#   "patch_size": 16,
#   "qkv_bias": true,
#   "transformers_version": "4.46.2"
# }
#
# Config of the decoder: <class 'transformers.models.gpt2.modeling_gpt2.GPT2LMHeadModel'> is overwritten by shared decoder config: GPT2Config {
#   "activation_function": "gelu_new",
#   "add_cross_attention": true,
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "decoder_start_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "is_decoder": true,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "pad_token_id": 50256,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.46.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
# preprocessor_config.json:   0%|          | 0.00/228 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/241 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]

# %%
# Función para generar captions
def generate_caption(image_path):
    # Cargar la imagen
    image = Image.open(image_path).convert("RGB")
    # Preprocesar la imagen
    pixel_values = feature_extractor(images=[image], return_tensors="pt").pixel_values

    # Generar el caption
    output_ids = model.generate(pixel_values)
    caption = tokenizer.decode(output_ids[0], skip_special_tokens=True)
    return caption

# Directorio donde se encuentran las imágenes
image_dir = "./data"

# Crear una lista para almacenar los resultados
results = []

# Recorrer los archivos en el directorio de imágenes
for idx, filename in enumerate(os.listdir(image_dir)):
    if filename.lower().endswith(('png', 'jpg', 'jpeg', 'bmp', 'gif', 'tiff')):
        # Generar el caption para cada imagen
        image_path = os.path.join(image_dir, filename)
        caption = generate_caption(image_path)
        # Agregar el resultado al DataFrame
        results.append({"ID": os.path.splitext(filename)[0], "caption": caption})

# Crear un DataFrame con los resultados
df = pd.DataFrame(results)
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1375: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# You may ignore this warning if your `pad_token_id` (50256) is identical to the `bos_token_id` (50256), `eos_token_id` (50256), or the `sep_token_id` (None), and your input is not padded.

# %%
df['ID'] = df['ID'].astype(int)
df = df.sort_values(by="ID").reset_index(drop=True)

# %%
df
# Out:
#       ID                                            caption
# 0      1            a man in a car with a sign on his head
# 1      2              a dog with a funny face on it's face
# 2      3                           a man in a suit and tie
# 3      4    a table with a picture of a cat and a toy frog
# 4      5                    a dog sitting on a wooden post
# ..   ...                                                ...
# 994  995            a collage of photos of a soccer player
# 995  996  a man holding a remote control in front of a w...
# 996  997  a man in a hospital bed with a heart shaped sign
# 997  998  a man in a suit and tie standing next to a gro...
# 998  999  a man with a black shirt and a black and white...
#
# [999 rows x 2 columns]

# %%
df.to_csv('vlt-imagecaptioning.csv',index=False)

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# Collecting googletrans==4.0.0-rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.10/dist-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.8.30)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.11.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17397 sha256=06506607f805aaadba455aadf3d1eb677c7004771c0a6d90effa9ea11c10fe50
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# Installing collected packages: googletrans
#   Attempting uninstall: googletrans
#     Found existing installation: googletrans 3.0.0
#     Uninstalling googletrans-3.0.0:
#       Successfully uninstalled googletrans-3.0.0
# Successfully installed googletrans-4.0.0rc1

# %%
df = pd.read_csv('vlt-imagecaptioning.csv')

# %%
df.to_csv('vlt-imagecaptioning.csv')

# %%
from googletrans import Translator

# Instanciar el traductor
translator = Translator()

# Función para traducir texto al español con manejo de errores
def translate_to_spanish(text):
    try:
        if text:  # Verificar que el texto no sea None o vacío
            translation = translator.translate(text, src='en', dest='es')
            return translation.text
        else:
            return ""  # Si el texto es None o vacío, devolver una cadena vacía
    except Exception as e:
        print(f"Error al traducir el texto: {text}. Error: {e}")
        return text  # Devolver el texto original si ocurre un error

# Traducir las captions al español directamente desde el DataFrame
df['caption_spanish'] = df['caption'].apply(translate_to_spanish)
# Out:
# Error al traducir el texto: a person on a snowboard . Error: 'NoneType' object is not iterable
# Error al traducir el texto: a dog laying on a white surface . Error: 'Translator' object has no attribute 'raise_Exception'
# Error al traducir el texto: a cartoon of a cartoon character with a computer . Error: 'Translator' object has no attribute 'raise_Exception'
# Error al traducir el texto: a dog is standing on a beach with a map . Error: 'Translator' object has no attribute 'raise_Exception'
# Error al traducir el texto: a cartoon of a cat with a heart shaped sign . Error: 'Translator' object has no attribute 'raise_Exception'
# Error al traducir el texto: a baseball player is holding a bat and a ball . Error: 'NoneType' object is not iterable
# Error al traducir el texto: a collage of photos of a cat and a dog . Error: 'Translator' object has no attribute 'raise_Exception'
# Error al traducir el texto: a collage of different colored images of a person . Error: 'Translator' object has no attribute 'raise_Exception'
# Error al traducir el texto: a black and white dog standing in the snow . Error: 'Translator' object has no attribute 'raise_Exception'
# Error al traducir el texto: a dog sitting on top of a table . Error: 'Translator' object has no attribute 'raise_Exception'
# Error al traducir el texto: a dog laying on a couch with a ball . Error: 'Translator' object has no attribute 'raise_Exception'
# Error al traducir el texto: a cat is sitting on a cat bed . Error: 'Translator' object has no attribute 'raise_Exception'
# Error al traducir el texto: a dog looking at a picture of a cat . Error: 'Translator' object has no attribute 'raise_Exception'
# Error al traducir el texto: a painting of a fire hydrant with a picture of a cat on it . Error: 'NoneType' object is not iterable
# Error al traducir el texto: a crowd of people watching a movie on a city street . Error: 'Translator' object has no attribute 'raise_Exception'
# Error al traducir el texto: a baby is laying in a bed with a white blanket . Error: 'NoneType' object is not iterable
# Error al traducir el texto: a collage of photos of a child in a hospital bed . Error: 'NoneType' object is not iterable
# Error al traducir el texto: a child with a toothbrush in his mouth . Error: 'NoneType' object is not iterable
# Error al traducir el texto: a small baby holding a stuffed animal . Error: 'NoneType' object is not iterable

# %%
df_new = df.drop(columns=['caption'])

# %%
df_new.rename(columns={'caption_spanish': 'caption'}, inplace=True)

# %%
df_new.to_csv('vlt-imagecaptioning_complete.csv',index=False,encoding='utf-8-sig')

# %%
df.shape
# Out:
# (999, 3)

# %% [markdown]
# # MÉTODO DE CAPTIONING 2 - BLIP IMAGE CAPTIONING BASE

# %%
#pip install transformers torch torchvision pillow

# %%
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image
import os
import pandas as pd

# %%
# Cargar el modelo BLIP y el procesador
model_name = "Salesforce/blip-image-captioning-base"
processor = BlipProcessor.from_pretrained(model_name)
model = BlipForConditionalGeneration.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]

# %%
# Función para generar captions con BLIP
def generate_blip_caption(image_path):
    try:
        image = Image.open(image_path).convert("RGB")
        inputs = processor(images=image, return_tensors="pt")
        outputs = model.generate(**inputs)
        caption = processor.decode(outputs[0], skip_special_tokens=True)
        print(f"Procesada correctamente: {os.path.basename(image_path)}")
        return caption
    except Exception as e:
        print(f"Error procesando la imagen {os.path.basename(image_path)}: {e}")
        return "Error al generar caption"

# Directorio donde se encuentran las imágenes
image_dir = "./data"  # Cambia esto a la ruta donde están tus imágenes

# Crear un DataFrame para almacenar los resultados
results = []

# Recorrer las imágenes en la carpeta
for idx, filename in enumerate(os.listdir(image_dir)):
    if filename.lower().endswith(('png', 'jpg', 'jpeg', 'bmp', 'gif', 'tiff')):
        image_path = os.path.join(image_dir, filename)
        caption = generate_blip_caption(image_path)
        results.append({"ID": os.path.splitext(filename)[0], "caption": caption})

# Crear un DataFrame con las captions
df = pd.DataFrame(results)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1375: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Procesada correctamente: 10.png
# Procesada correctamente: 434.jpeg
# Procesada correctamente: 440.jpeg
# Procesada correctamente: 607.jpeg
# Procesada correctamente: 90.jpeg
# Procesada correctamente: 170.jpeg
# Procesada correctamente: 648.jpeg
# Procesada correctamente: 450.jpeg
# Procesada correctamente: 75.jpeg
# Procesada correctamente: 397.jpeg
# Procesada correctamente: 197.jpeg
# Procesada correctamente: 172.png
# Procesada correctamente: 31.jpeg
# Procesada correctamente: 727.jpeg
# Procesada correctamente: 333.jpeg
# Procesada correctamente: 126.jpeg
# Procesada correctamente: 526.png
# Procesada correctamente: 145.jpeg
# Procesada correctamente: 866.jpeg
# Procesada correctamente: 188.jpeg
# Procesada correctamente: 108.jpeg
# Procesada correctamente: 1.png
# Procesada correctamente: 524.jpeg
# Procesada correctamente: 449.png
# Procesada correctamente: 395.jpeg
# Procesada correctamente: 665.jpeg
# Procesada correctamente: 144.jpeg
# Procesada correctamente: 942.jpeg
# Procesada correctamente: 551.jpeg
# Procesada correctamente: 288.jpeg
# Procesada correctamente: 639.jpeg
# Procesada correctamente: 181.jpeg
# Procesada correctamente: 492.jpeg
# Procesada correctamente: 372.png
# Procesada correctamente: 299.jpeg
# Procesada correctamente: 594.jpeg
# Procesada correctamente: 570.jpeg
# Procesada correctamente: 544.jpeg
# Procesada correctamente: 243.jpeg
# Procesada correctamente: 420.jpeg
# Procesada correctamente: 110.jpeg
# Procesada correctamente: 592.jpeg
# Procesada correctamente: 554.jpeg
# Procesada correctamente: 793.jpeg
# Procesada correctamente: 50.png
# Procesada correctamente: 296.jpeg
# Procesada correctamente: 667.jpeg
# Procesada correctamente: 731.jpeg
# Procesada correctamente: 883.jpeg
# Procesada correctamente: 100.jpeg
# Procesada correctamente: 390.jpeg
# Procesada correctamente: 861.jpeg
# Procesada correctamente: 700.jpeg
# Procesada correctamente: 398.jpeg
# Procesada correctamente: 584.jpeg
# Procesada correctamente: 21.jpeg
# Procesada correctamente: 785.jpeg
# Procesada correctamente: 3.png
# Procesada correctamente: 429.jpeg
# Procesada correctamente: 494.jpeg
# Procesada correctamente: 586.jpeg
# Procesada correctamente: 438.jpeg
# Procesada correctamente: 63.jpeg
# Procesada correctamente: 137.jpeg
# Procesada correctamente: 523.jpeg
# Procesada correctamente: 563.jpeg
# Procesada correctamente: 987.png
# Procesada correctamente: 378.jpeg
# Procesada correctamente: 657.png
# Procesada correctamente: 777.jpeg
# Procesada correctamente: 361.png
# Procesada correctamente: 59.jpeg
# Procesada correctamente: 479.jpeg
# Procesada correctamente: 432.jpeg
# Procesada correctamente: 538.jpeg
# Procesada correctamente: 314.jpeg
# Procesada correctamente: 847.jpeg
# Procesada correctamente: 661.jpeg
# Procesada correctamente: 951.jpeg
# Procesada correctamente: 205.png
# Procesada correctamente: 922.jpeg
# Procesada correctamente: 196.jpeg
# Procesada correctamente: 724.jpeg
# Procesada correctamente: 435.jpeg
# Procesada correctamente: 229.jpeg
# Procesada correctamente: 719.jpeg
# Procesada correctamente: 642.jpeg
# Procesada correctamente: 12.png
# Procesada correctamente: 886.jpeg
# Procesada correctamente: 410.jpeg
# Procesada correctamente: 336.jpeg
# Procesada correctamente: 672.jpeg
# Procesada correctamente: 794.jpeg
# Procesada correctamente: 499.jpeg
# Procesada correctamente: 822.jpeg
# Procesada correctamente: 130.jpeg
# Procesada correctamente: 391.jpeg
# Procesada correctamente: 656.jpeg
# Procesada correctamente: 498.jpeg
# Procesada correctamente: 239.png
# Procesada correctamente: 848.jpeg
# Procesada correctamente: 713.png
# Procesada correctamente: 788.jpeg
# Procesada correctamente: 790.png
# Procesada correctamente: 804.jpeg
# Procesada correctamente: 443.jpeg
# Procesada correctamente: 566.jpeg
# Procesada correctamente: 877.jpeg
# Procesada correctamente: 73.jpeg
# Procesada correctamente: 26.jpeg
# Procesada correctamente: 906.jpeg
# Procesada correctamente: 773.jpeg
# Procesada correctamente: 747.jpeg
# Procesada correctamente: 362.jpeg
# Procesada correctamente: 876.jpeg
# Procesada correctamente: 897.jpeg
# Procesada correctamente: 70.jpeg
# Procesada correctamente: 702.png
# Procesada correctamente: 843.jpeg
# Procesada correctamente: 104.jpeg
# Procesada correctamente: 326.jpeg
# Procesada correctamente: 881.jpeg
# Procesada correctamente: 704.jpeg
# Procesada correctamente: 473.jpeg
# Procesada correctamente: 805.jpeg
# Procesada correctamente: 795.jpeg
# Procesada correctamente: 376.jpeg
# Procesada correctamente: 64.jpeg
# Procesada correctamente: 285.jpeg
# Procesada correctamente: 81.jpeg
# Procesada correctamente: 556.jpeg
# Procesada correctamente: 728.jpeg
# Procesada correctamente: 596.jpeg
# Procesada correctamente: 121.jpeg
# Procesada correctamente: 500.jpeg
# Procesada correctamente: 685.jpeg
# Procesada correctamente: 153.jpeg
# Procesada correctamente: 969.jpeg
# Procesada correctamente: 132.jpeg
# Procesada correctamente: 824.jpeg
# Procesada correctamente: 994.png
# Procesada correctamente: 327.png
# Procesada correctamente: 247.jpeg
# Procesada correctamente: 828.jpeg
# Procesada correctamente: 913.jpeg
# Procesada correctamente: 920.jpeg
# Procesada correctamente: 761.jpeg
# Procesada correctamente: 256.jpeg
# Procesada correctamente: 609.jpeg
# Procesada correctamente: 599.jpeg
# Procesada correctamente: 165.jpeg
# Procesada correctamente: 509.jpeg
# Procesada correctamente: 274.jpeg
# Procesada correctamente: 930.jpeg
# Procesada correctamente: 331.jpeg
# Procesada correctamente: 169.jpeg
# Procesada correctamente: 359.jpeg
# Procesada correctamente: 829.jpeg
# Procesada correctamente: 426.png
# Procesada correctamente: 303.jpeg
# Procesada correctamente: 275.jpeg
# Procesada correctamente: 244.jpeg
# Procesada correctamente: 587.jpeg
# Procesada correctamente: 82.jpeg
# Procesada correctamente: 933.jpeg
# Procesada correctamente: 783.jpeg
# Procesada correctamente: 134.jpeg
# Procesada correctamente: 625.jpeg
# Procesada correctamente: 495.jpeg
# Procesada correctamente: 202.jpeg
# Procesada correctamente: 192.jpeg
# Procesada correctamente: 236.jpeg
# Procesada correctamente: 746.jpeg
# Procesada correctamente: 505.jpeg
# Procesada correctamente: 6.jpeg
# Procesada correctamente: 241.jpeg
# Procesada correctamente: 101.jpeg
# Procesada correctamente: 179.jpeg
# Procesada correctamente: 608.jpeg
# Procesada correctamente: 902.jpeg
# Procesada correctamente: 814.jpeg
# Procesada correctamente: 107.jpeg
# Procesada correctamente: 284.jpeg
# Procesada correctamente: 489.jpeg
# Procesada correctamente: 164.jpeg
# Procesada correctamente: 986.png
# Procesada correctamente: 266.jpeg
# Procesada correctamente: 932.jpeg
# Procesada correctamente: 531.jpeg
# Procesada correctamente: 463.jpeg
# Procesada correctamente: 645.jpeg
# Procesada correctamente: 158.jpeg
# Procesada correctamente: 600.jpeg
# Procesada correctamente: 641.jpeg
# Procesada correctamente: 17.png
# Procesada correctamente: 315.jpeg
# Procesada correctamente: 451.jpeg
# Procesada correctamente: 908.jpeg
# Procesada correctamente: 658.jpeg
# Procesada correctamente: 106.jpeg
# Procesada correctamente: 442.jpeg
# Procesada correctamente: 423.jpeg
# Procesada correctamente: 259.jpeg
# Procesada correctamente: 355.jpeg
# Procesada correctamente: 593.jpeg
# Procesada correctamente: 324.jpeg
# Procesada correctamente: 71.jpeg
# Procesada correctamente: 921.jpeg
# Procesada correctamente: 286.jpeg
# Procesada correctamente: 309.jpeg
# Procesada correctamente: 250.png
# Procesada correctamente: 403.jpeg
# Procesada correctamente: 260.jpeg
# Procesada correctamente: 742.jpeg
# Procesada correctamente: 845.png
# Procesada correctamente: 46.jpeg
# Procesada correctamente: 546.jpeg
# Procesada correctamente: 677.jpeg
# Procesada correctamente: 187.jpeg
# Procesada correctamente: 938.jpeg
# Procesada correctamente: 511.jpeg
# Procesada correctamente: 323.jpeg
# Procesada correctamente: 588.jpeg
# Procesada correctamente: 340.jpeg
# Procesada correctamente: 338.png
# Procesada correctamente: 888.jpeg
# Procesada correctamente: 744.jpeg
# Procesada correctamente: 855.jpeg
# Procesada correctamente: 512.jpeg
# Procesada correctamente: 486.jpeg
# Procesada correctamente: 319.jpeg
# Procesada correctamente: 180.jpeg
# Procesada correctamente: 912.png
# Procesada correctamente: 322.jpeg
# Procesada correctamente: 835.jpeg
# Procesada correctamente: 457.jpeg
# Procesada correctamente: 45.jpeg
# Procesada correctamente: 739.jpeg
# Procesada correctamente: 518.jpeg
# Procesada correctamente: 459.jpeg
# Procesada correctamente: 852.jpeg
# Procesada correctamente: 809.jpeg
# Procesada correctamente: 939.jpeg
# Procesada correctamente: 161.png
# Procesada correctamente: 19.png
# Procesada correctamente: 623.jpeg
# Procesada correctamente: 37.jpeg
# Procesada correctamente: 669.png
# Procesada correctamente: 561.jpeg
# Procesada correctamente: 555.jpeg
# Procesada correctamente: 627.jpeg
# Procesada correctamente: 670.jpeg
# Procesada correctamente: 703.jpeg
# Procesada correctamente: 218.jpeg
# Procesada correctamente: 649.jpeg
# Procesada correctamente: 630.jpeg
# Procesada correctamente: 88.jpeg
# Procesada correctamente: 328.jpeg
# Procesada correctamente: 534.jpeg
# Procesada correctamente: 582.jpeg
# Procesada correctamente: 767.png
# Procesada correctamente: 9.png
# Procesada correctamente: 738.jpeg
# Procesada correctamente: 350.png
# Procesada correctamente: 67.jpeg
# Procesada correctamente: 910.jpeg
# Procesada correctamente: 388.jpeg
# Procesada correctamente: 756.png
# Procesada correctamente: 232.jpeg
# Procesada correctamente: 149.jpeg
# Procesada correctamente: 891.jpeg
# Procesada correctamente: 620.jpeg
# Procesada correctamente: 851.jpeg
# Procesada correctamente: 198.jpeg
# Procesada correctamente: 635.png
# Procesada correctamente: 559.jpeg
# Procesada correctamente: 820.jpeg
# Procesada correctamente: 903.jpeg
# Procesada correctamente: 41.jpeg
# Procesada correctamente: 961.jpeg
# Procesada correctamente: 349.jpeg
# Procesada correctamente: 578.jpeg
# Procesada correctamente: 113.jpeg
# Procesada correctamente: 691.png
# Procesada correctamente: 445.jpeg
# Procesada correctamente: 603.jpeg
# Procesada correctamente: 871.jpeg
# Procesada correctamente: 696.jpeg
# Procesada correctamente: 834.png
# Procesada correctamente: 377.jpeg
# Procesada correctamente: 424.jpeg
# Procesada correctamente: 934.png
# Procesada correctamente: 916.jpeg
# Procesada correctamente: 240.jpeg
# Procesada correctamente: 950.jpeg
# Procesada correctamente: 321.jpeg
# Procesada correctamente: 273.jpeg
# Procesada correctamente: 711.jpeg
# Procesada correctamente: 619.jpeg
# Procesada correctamente: 262.jpeg
# Procesada correctamente: 753.jpeg
# Procesada correctamente: 628.jpeg
# Procesada correctamente: 769.jpeg
# Procesada correctamente: 688.jpeg
# Procesada correctamente: 265.jpeg
# Procesada correctamente: 97.jpeg
# Procesada correctamente: 248.jpeg
# Procesada correctamente: 872.jpeg
# Procesada correctamente: 904.jpeg
# Procesada correctamente: 652.jpeg
# Procesada correctamente: 111.jpeg
# Procesada correctamente: 345.jpeg
# Procesada correctamente: 135.jpeg
# Procesada correctamente: 402.jpeg
# Procesada correctamente: 298.jpeg
# Procesada correctamente: 535.jpeg
# Procesada correctamente: 825.jpeg
# Procesada correctamente: 404.png
# Procesada correctamente: 763.jpeg
# Procesada correctamente: 754.jpeg
# Procesada correctamente: 651.jpeg
# Procesada correctamente: 857.jpeg
# Procesada correctamente: 23.jpeg
# Procesada correctamente: 267.jpeg
# Procesada correctamente: 283.png
# Procesada correctamente: 427.jpeg
# Procesada correctamente: 467.jpeg
# Procesada correctamente: 833.jpeg
# Procesada correctamente: 547.jpeg
# Procesada correctamente: 811.jpeg
# Procesada correctamente: 430.jpeg
# Procesada correctamente: 8.png
# Procesada correctamente: 219.jpeg
# Procesada correctamente: 816.jpeg
# Procesada correctamente: 941.jpeg
# Procesada correctamente: 810.jpeg
# Procesada correctamente: 943.jpeg
# Procesada correctamente: 203.jpeg
# Procesada correctamente: 798.jpeg
# Procesada correctamente: 157.jpeg
# Procesada correctamente: 171.jpeg
# Procesada correctamente: 927.jpeg
# Procesada correctamente: 125.jpeg
# Procesada correctamente: 695.jpeg
# Procesada correctamente: 675.jpeg
# Procesada correctamente: 676.jpeg
# Procesada correctamente: 399.jpeg
# Procesada correctamente: 191.jpeg
# Procesada correctamente: 537.png
# Procesada correctamente: 51.jpeg
# Procesada correctamente: 640.jpeg
# Procesada correctamente: 94.png
# Procesada correctamente: 979.png
# Procesada correctamente: 870.jpeg
# Procesada correctamente: 760.jpeg
# Procesada correctamente: 22.jpeg
# Procesada correctamente: 821.jpeg
# Procesada correctamente: 952.jpeg
# Procesada correctamente: 768.jpeg
# Procesada correctamente: 329.jpeg
# Procesada correctamente: 565.jpeg
# Procesada correctamente: 291.jpeg
# Procesada correctamente: 840.jpeg
# Procesada correctamente: 770.jpeg
# Procesada correctamente: 988.png
# Procesada correctamente: 571.jpeg
# Procesada correctamente: 253.jpeg
# Procesada correctamente: 543.jpeg
# Procesada correctamente: 407.jpeg
# Procesada correctamente: 844.jpeg
# Procesada correctamente: 955.jpeg
# Procesada correctamente: 292.jpeg
# Procesada correctamente: 576.jpeg
# Procesada correctamente: 141.jpeg
# Procesada correctamente: 416.jpeg
# Procesada correctamente: 13.png
# Procesada correctamente: 981.png
# Procesada correctamente: 758.jpeg
# Procesada correctamente: 14.png
# Procesada correctamente: 617.jpeg
# Procesada correctamente: 34.jpeg
# Procesada correctamente: 207.jpeg
# Procesada correctamente: 850.jpeg
# Procesada correctamente: 936.jpeg
# Procesada correctamente: 20.png
# Procesada correctamente: 664.jpeg
# Procesada correctamente: 72.png
# Procesada correctamente: 819.jpeg
# Procesada correctamente: 945.png
# Procesada correctamente: 184.jpeg
# Procesada correctamente: 784.jpeg
# Procesada correctamente: 25.jpeg
# Procesada correctamente: 741.jpeg
# Procesada correctamente: 993.png
# Procesada correctamente: 270.jpeg
# Procesada correctamente: 139.png
# Procesada correctamente: 123.jpeg
# Procesada correctamente: 882.jpeg
# Procesada correctamente: 725.jpeg
# Procesada correctamente: 189.jpeg
# Procesada correctamente: 452.jpeg
# Procesada correctamente: 750.jpeg
# Procesada correctamente: 30.jpeg
# Procesada correctamente: 972.jpeg
# Procesada correctamente: 477.jpeg
# Procesada correctamente: 612.jpeg
# Procesada correctamente: 553.jpeg
# Procesada correctamente: 684.jpeg
# Procesada correctamente: 356.jpeg
# Procesada correctamente: 510.jpeg
# Procesada correctamente: 899.jpeg
# Procesada correctamente: 182.jpeg
# Procesada correctamente: 490.jpeg
# Procesada correctamente: 967.png
# Procesada correctamente: 35.jpeg
# Procesada correctamente: 721.jpeg
# Procesada correctamente: 472.jpeg
# Procesada correctamente: 150.png
# Procesada correctamente: 441.jpeg
# Procesada correctamente: 668.png
# Procesada correctamente: 705.jpeg
# Procesada correctamente: 419.jpeg
# Procesada correctamente: 683.jpeg
# Procesada correctamente: 233.jpeg
# Procesada correctamente: 898.jpeg
# Procesada correctamente: 878.jpeg
# Procesada correctamente: 954.jpeg
# Procesada correctamente: 405.jpeg
# Procesada correctamente: 385.jpeg
# Procesada correctamente: 577.jpeg
# Procesada correctamente: 475.jpeg
# Procesada correctamente: 839.jpeg
# Procesada correctamente: 367.jpeg
# Procesada correctamente: 504.png
# Procesada correctamente: 269.jpeg
# Procesada correctamente: 310.jpeg
# Procesada correctamente: 748.jpeg
# Procesada correctamente: 4.jpeg
# Procesada correctamente: 832.jpeg
# Procesada correctamente: 737.jpeg
# Procesada correctamente: 339.png
# Procesada correctamente: 462.jpeg
# Procesada correctamente: 496.jpeg
# Procesada correctamente: 300.jpeg
# Procesada correctamente: 650.jpeg
# Procesada correctamente: 973.jpeg
# Procesada correctamente: 379.jpeg
# Procesada correctamente: 40.jpeg
# Procesada correctamente: 195.jpeg
# Procesada correctamente: 461.jpeg
# Procesada correctamente: 968.jpeg
# Procesada correctamente: 690.jpeg
# Procesada correctamente: 166.jpeg
# Procesada correctamente: 830.jpeg
# Procesada correctamente: 65.jpeg
# Procesada correctamente: 837.jpeg
# Procesada correctamente: 2.png
# Procesada correctamente: 863.jpeg
# Procesada correctamente: 348.jpeg
# Procesada correctamente: 759.jpeg
# Procesada correctamente: 716.jpeg
# Procesada correctamente: 779.png
# Procesada correctamente: 812.png
# Procesada correctamente: 598.jpeg
# Procesada correctamente: 960.jpeg
# Procesada correctamente: 957.jpeg
# Procesada correctamente: 964.jpeg
# Procesada correctamente: 887.jpeg
# Procesada correctamente: 268.jpeg
# Procesada correctamente: 666.jpeg
# Procesada correctamente: 963.jpeg
# Procesada correctamente: 116.png
# Procesada correctamente: 971.jpeg
# Procesada correctamente: 517.jpeg
# Procesada correctamente: 818.jpeg
# Procesada correctamente: 919.jpeg
# Procesada correctamente: 305.png
# Procesada correctamente: 560.jpeg
# Procesada correctamente: 506.jpeg
# Procesada correctamente: 616.jpeg
# Procesada correctamente: 190.jpeg
# Procesada correctamente: 782.jpeg
# Procesada correctamente: 634.jpeg
# Procesada correctamente: 991.png
# Procesada correctamente: 854.png
# Procesada correctamente: 221.jpeg
# Procesada correctamente: 210.jpeg
# Procesada correctamente: 733.jpeg
# Procesada correctamente: 846.jpeg
# Procesada correctamente: 212.jpeg
# Procesada correctamente: 234.jpeg
# Procesada correctamente: 48.jpeg
# Procesada correctamente: 301.jpeg
# Procesada correctamente: 69.jpeg
# Procesada correctamente: 16.png
# Procesada correctamente: 389.jpeg
# Procesada correctamente: 168.jpeg
# Procesada correctamente: 152.jpeg
# Procesada correctamente: 514.jpeg
# Procesada correctamente: 655.jpeg
# Procesada correctamente: 697.jpeg
# Procesada correctamente: 471.png
# Procesada correctamente: 803.jpeg
# Procesada correctamente: 823.png
# Procesada correctamente: 387.jpeg
# Procesada correctamente: 118.jpeg
# Procesada correctamente: 448.png
# Procesada correctamente: 914.jpeg
# Procesada correctamente: 456.jpeg
# Procesada correctamente: 838.jpeg
# Procesada correctamente: 875.jpeg
# Procesada correctamente: 513.jpeg
# Procesada correctamente: 907.jpeg
# Procesada correctamente: 68.jpeg
# Procesada correctamente: 564.jpeg
# Procesada correctamente: 29.jpeg
# Procesada correctamente: 201.jpeg
# Procesada correctamente: 800.jpeg
# Procesada correctamente: 366.jpeg
# Procesada correctamente: 712.jpeg
# Procesada correctamente: 464.jpeg
# Procesada correctamente: 127.jpeg
# Procesada correctamente: 98.jpeg
# Procesada correctamente: 374.jpeg
# Procesada correctamente: 52.jpeg
# Procesada correctamente: 136.jpeg
# Procesada correctamente: 729.jpeg
# Procesada correctamente: 32.jpeg
# Procesada correctamente: 791.jpeg
# Procesada correctamente: 611.jpeg
# Procesada correctamente: 673.jpeg
# Procesada correctamente: 923.png
# Procesada correctamente: 371.jpeg
# Procesada correctamente: 982.png
# Procesada correctamente: 799.jpeg
# Procesada correctamente: 944.jpeg
# Procesada correctamente: 368.jpeg
# Procesada correctamente: 263.jpeg
# Procesada correctamente: 431.jpeg
# Procesada correctamente: 325.jpeg
# Procesada correctamente: 862.jpeg
# Procesada correctamente: 220.jpeg
# Procesada correctamente: 802.jpeg
# Procesada correctamente: 74.jpeg
# Procesada correctamente: 998.png
# Procesada correctamente: 868.png
# Procesada correctamente: 826.jpeg
# Procesada correctamente: 162.jpeg
# Procesada correctamente: 279.jpeg
# Procesada correctamente: 332.jpeg
# Procesada correctamente: 574.jpeg
# Procesada correctamente: 466.jpeg
# Procesada correctamente: 257.jpeg
# Procesada correctamente: 154.jpeg
# Procesada correctamente: 208.jpeg
# Procesada correctamente: 604.jpeg
# Procesada correctamente: 807.jpeg
# Procesada correctamente: 159.jpeg
# Procesada correctamente: 726.jpeg
# Procesada correctamente: 453.jpeg
# Procesada correctamente: 174.jpeg
# Procesada correctamente: 772.jpeg
# Procesada correctamente: 996.png
# Procesada correctamente: 654.jpeg
# Procesada correctamente: 521.jpeg
# Procesada correctamente: 931.jpeg
# Procesada correctamente: 699.jpeg
# Procesada correctamente: 358.jpeg
# Procesada correctamente: 344.jpeg
# Procesada correctamente: 261.png
# Procesada correctamente: 895.jpeg
# Procesada correctamente: 890.png
# Procesada correctamente: 797.jpeg
# Procesada correctamente: 444.jpeg
# Procesada correctamente: 806.jpeg
# Procesada correctamente: 277.jpeg
# Procesada correctamente: 401.jpeg
# Procesada correctamente: 613.png
# Procesada correctamente: 66.jpeg
# Procesada correctamente: 787.jpeg
# Procesada correctamente: 455.jpeg
# Procesada correctamente: 621.jpeg
# Procesada correctamente: 618.jpeg
# Procesada correctamente: 989.png
# Procesada correctamente: 206.jpeg
# Procesada correctamente: 493.png
# Procesada correctamente: 227.png
# Procesada correctamente: 373.jpeg
# Procesada correctamente: 276.jpeg
# Procesada correctamente: 734.png
# Procesada correctamente: 406.jpeg
# Procesada correctamente: 928.jpeg
# Procesada correctamente: 730.jpeg
# Procesada correctamente: 575.jpeg
# Procesada correctamente: 929.jpeg
# Procesada correctamente: 317.jpeg
# Procesada correctamente: 956.png
# Procesada correctamente: 167.jpeg
# Procesada correctamente: 948.jpeg
# Procesada correctamente: 293.jpeg
# Procesada correctamente: 775.jpeg
# Procesada correctamente: 589.jpeg
# Procesada correctamente: 245.jpeg
# Procesada correctamente: 99.jpeg
# Procesada correctamente: 422.jpeg
# Procesada correctamente: 396.jpeg
# Procesada correctamente: 316.png
# Procesada correctamente: 84.jpeg
# Procesada correctamente: 412.jpeg
# Procesada correctamente: 39.png
# Procesada correctamente: 815.jpeg
# Procesada correctamente: 629.jpeg
# Procesada correctamente: 900.jpeg
# Procesada correctamente: 209.jpeg
# Procesada correctamente: 468.jpeg
# Procesada correctamente: 383.png
# Procesada correctamente: 918.jpeg
# Procesada correctamente: 230.jpeg
# Procesada correctamente: 671.jpeg
# Procesada correctamente: 173.jpeg
# Procesada correctamente: 853.jpeg
# Procesada correctamente: 894.jpeg
# Procesada correctamente: 980.png
# Procesada correctamente: 663.jpeg
# Procesada correctamente: 548.png
# Procesada correctamente: 698.jpeg
# Procesada correctamente: 522.jpeg
# Procesada correctamente: 238.jpeg
# Procesada correctamente: 421.jpeg
# Procesada correctamente: 615.jpeg
# Procesada correctamente: 519.jpeg
# Procesada correctamente: 57.jpeg
# Procesada correctamente: 962.jpeg
# Procesada correctamente: 470.jpeg
# Procesada correctamente: 411.jpeg
# Procesada correctamente: 662.jpeg
# Procesada correctamente: 953.jpeg
# Procesada correctamente: 827.jpeg
# Procesada correctamente: 11.png
# Procesada correctamente: 364.jpeg
# Procesada correctamente: 290.jpeg
# Procesada correctamente: 228.png
# Procesada correctamente: 151.jpeg
# Procesada correctamente: 408.jpeg
# Procesada correctamente: 885.jpeg
# Procesada correctamente: 446.jpeg
# Procesada correctamente: 370.jpeg
# Procesada correctamente: 380.jpeg
# Procesada correctamente: 55.jpeg
# Procesada correctamente: 24.jpeg
# Procesada correctamente: 636.jpeg
# Procesada correctamente: 970.jpeg
# Procesada correctamente: 976.jpeg
# Procesada correctamente: 92.jpeg
# Procesada correctamente: 93.jpeg
# Procesada correctamente: 997.png
# Procesada correctamente: 304.jpeg
# Procesada correctamente: 246.jpeg
# Procesada correctamente: 363.jpeg
# Procesada correctamente: 83.png
# Procesada correctamente: 302.jpeg
# Procesada correctamente: 926.jpeg
# Procesada correctamente: 484.jpeg
# Procesada correctamente: 204.jpeg
# Procesada correctamente: 393.jpeg
# Procesada correctamente: 381.jpeg
# Procesada correctamente: 978.png
# Procesada correctamente: 418.jpeg
# Procesada correctamente: 199.jpeg
# Procesada correctamente: 771.jpeg
# Procesada correctamente: 550.jpeg
# Procesada correctamente: 638.jpeg
# Procesada correctamente: 503.jpeg
# Procesada correctamente: 38.jpeg
# Procesada correctamente: 129.jpeg
# Procesada correctamente: 502.jpeg
# Procesada correctamente: 222.jpeg
# Procesada correctamente: 330.jpeg
# Procesada correctamente: 692.jpeg
# Procesada correctamente: 567.jpeg
# Procesada correctamente: 481.jpeg
# Procesada correctamente: 242.jpeg
# Procesada correctamente: 765.jpeg
# Procesada correctamente: 146.jpeg
# Procesada correctamente: 515.png
# Procesada correctamente: 54.jpeg
# Procesada correctamente: 211.jpeg
# Procesada correctamente: 562.jpeg
# Procesada correctamente: 985.png
# Procesada correctamente: 622.jpeg
# Procesada correctamente: 47.jpeg
# Procesada correctamente: 102.jpeg
# Procesada correctamente: 999.png
# Procesada correctamente: 156.jpeg
# Procesada correctamente: 915.jpeg
# Procesada correctamente: 353.jpeg
# Procesada correctamente: 237.jpeg
# Procesada correctamente: 896.jpeg
# Procesada correctamente: 715.jpeg
# Procesada correctamente: 400.jpeg
# Procesada correctamente: 128.png
# Procesada correctamente: 43.jpeg
# Procesada correctamente: 718.jpeg
# Procesada correctamente: 194.png
# Procesada correctamente: 428.jpeg
# Procesada correctamente: 439.jpeg
# Procesada correctamente: 545.jpeg
# Procesada correctamente: 458.jpeg
# Procesada correctamente: 529.jpeg
# Procesada correctamente: 44.jpeg
# Procesada correctamente: 308.jpeg
# Procesada correctamente: 601.jpeg
# Procesada correctamente: 880.jpeg
# Procesada correctamente: 357.jpeg
# Procesada correctamente: 722.jpeg
# Procesada correctamente: 889.jpeg
# Procesada correctamente: 542.jpeg
# Procesada correctamente: 949.jpeg
# Procesada correctamente: 977.jpeg
# Procesada correctamente: 796.jpeg
# Procesada correctamente: 114.jpeg
# Procesada correctamente: 755.jpeg
# Procesada correctamente: 53.jpeg
# Procesada correctamente: 287.jpeg
# Procesada correctamente: 541.jpeg
# Procesada correctamente: 7.jpeg
# Procesada correctamente: 115.jpeg
# Procesada correctamente: 947.jpeg
# Procesada correctamente: 109.jpeg
# Procesada correctamente: 558.png
# Procesada correctamente: 924.jpeg
# Procesada correctamente: 792.jpeg
# Procesada correctamente: 365.jpeg
# Procesada correctamente: 375.jpeg
# Procesada correctamente: 482.png
# Procesada correctamente: 413.jpeg
# Procesada correctamente: 175.jpeg
# Procesada correctamente: 436.jpeg
# Procesada correctamente: 148.jpeg
# Procesada correctamente: 653.jpeg
# Procesada correctamente: 975.jpeg
# Procesada correctamente: 631.jpeg
# Procesada correctamente: 297.jpeg
# Procesada correctamente: 341.jpeg
# Procesada correctamente: 856.jpeg
# Procesada correctamente: 56.jpeg
# Procesada correctamente: 680.png
# Procesada correctamente: 689.jpeg
# Procesada correctamente: 251.jpeg
# Procesada correctamente: 176.jpeg
# Procesada correctamente: 447.jpeg
# Procesada correctamente: 425.jpeg
# Procesada correctamente: 225.jpeg
# Procesada correctamente: 992.png
# Procesada correctamente: 5.jpeg
# Procesada correctamente: 437.png
# Procesada correctamente: 354.jpeg
# Procesada correctamente: 723.png
# Procesada correctamente: 762.jpeg
# Procesada correctamente: 766.jpeg
# Procesada correctamente: 757.jpeg
# Procesada correctamente: 155.jpeg
# Procesada correctamente: 488.jpeg
# Procesada correctamente: 808.jpeg
# Procesada correctamente: 163.jpeg
# Procesada correctamente: 483.jpeg
# Procesada correctamente: 160.jpeg
# Procesada correctamente: 351.jpeg
# Procesada correctamente: 735.jpeg
# Procesada correctamente: 959.jpeg
# Procesada correctamente: 140.jpeg
# Procesada correctamente: 530.jpeg
# Procesada correctamente: 776.jpeg
# Procesada correctamente: 678.jpeg
# Procesada correctamente: 18.png
# Procesada correctamente: 909.jpeg
# Procesada correctamente: 743.jpeg
# Procesada correctamente: 87.jpeg
# Procesada correctamente: 752.jpeg
# Procesada correctamente: 874.jpeg
# Procesada correctamente: 813.jpeg
# Procesada correctamente: 706.jpeg
# Procesada correctamente: 77.jpeg
# Procesada correctamente: 313.jpeg
# Procesada correctamente: 119.jpeg
# Procesada correctamente: 595.jpeg
# Procesada correctamente: 255.jpeg
# Procesada correctamente: 42.jpeg
# Procesada correctamente: 469.jpeg
# Procesada correctamente: 749.jpeg
# Procesada correctamente: 335.jpeg
# Procesada correctamente: 984.png
# Procesada correctamente: 525.jpeg
# Procesada correctamente: 679.jpeg
# Procesada correctamente: 516.jpeg
# Procesada correctamente: 995.png
# Procesada correctamente: 836.jpeg
# Procesada correctamente: 28.png
# Procesada correctamente: 637.jpeg
# Procesada correctamente: 112.jpeg
# Procesada correctamente: 258.jpeg
# Procesada correctamente: 925.jpeg
# Procesada correctamente: 701.jpeg
# Procesada correctamente: 873.jpeg
# Procesada correctamente: 347.jpeg
# Procesada correctamente: 643.jpeg
# Procesada correctamente: 280.jpeg
# Procesada correctamente: 343.jpeg
# Procesada correctamente: 745.png
# Procesada correctamente: 717.jpeg
# Procesada correctamente: 901.png
# Procesada correctamente: 633.jpeg
# Procesada correctamente: 320.jpeg
# Procesada correctamente: 591.png
# Procesada correctamente: 693.jpeg
# Procesada correctamente: 520.jpeg
# Procesada correctamente: 318.jpeg
# Procesada correctamente: 79.jpeg
# Procesada correctamente: 606.jpeg
# Procesada correctamente: 624.png
# Procesada correctamente: 311.jpeg
# Procesada correctamente: 95.jpeg
# Procesada correctamente: 646.png
# Procesada correctamente: 306.jpeg
# Procesada correctamente: 686.jpeg
# Procesada correctamente: 382.jpeg
# Procesada correctamente: 860.jpeg
# Procesada correctamente: 572.jpeg
# Procesada correctamente: 409.jpeg
# Procesada correctamente: 120.jpeg
# Procesada correctamente: 235.jpeg
# Procesada correctamente: 801.png
# Procesada correctamente: 626.jpeg
# Procesada correctamente: 78.jpeg
# Procesada correctamente: 478.jpeg
# Procesada correctamente: 252.jpeg
# Procesada correctamente: 774.jpeg
# Procesada correctamente: 842.jpeg
# Procesada correctamente: 597.jpeg
# Procesada correctamente: 602.png
# Procesada correctamente: 337.jpeg
# Procesada correctamente: 226.jpeg
# Procesada correctamente: 415.png
# Procesada correctamente: 177.jpeg
# Procesada correctamente: 264.jpeg
# Procesada correctamente: 178.jpeg
# Procesada correctamente: 272.png
# Procesada correctamente: 501.jpeg
# Procesada correctamente: 539.jpeg
# Procesada correctamente: 709.jpeg
# Procesada correctamente: 781.jpeg
# Procesada correctamente: 485.jpeg
# Procesada correctamente: 183.png
# Procesada correctamente: 581.jpeg
# Procesada correctamente: 865.jpeg
# Procesada correctamente: 342.jpeg
# Procesada correctamente: 674.jpeg
# Procesada correctamente: 249.jpeg
# Procesada correctamente: 935.jpeg
# Procesada correctamente: 864.jpeg
# Procesada correctamente: 147.jpeg
# Procesada correctamente: 687.jpeg
# Procesada correctamente: 940.jpeg
# Procesada correctamente: 85.jpeg
# Procesada correctamente: 917.jpeg
# Procesada correctamente: 216.png
# Procesada correctamente: 49.jpeg
# Procesada correctamente: 476.jpeg
# Procesada correctamente: 580.png
# Procesada correctamente: 417.jpeg
# Procesada correctamente: 644.jpeg
# Procesada correctamente: 983.png
# Procesada correctamente: 732.jpeg
# Procesada correctamente: 142.jpeg
# Procesada correctamente: 720.jpeg
# Procesada correctamente: 632.jpeg
# Procesada correctamente: 254.jpeg
# Procesada correctamente: 214.jpeg
# Procesada correctamente: 714.jpeg
# Procesada correctamente: 433.jpeg
# Procesada correctamente: 392.jpeg
# Procesada correctamente: 778.png
# Procesada correctamente: 138.jpeg
# Procesada correctamente: 103.jpeg
# Procesada correctamente: 585.jpeg
# Procesada correctamente: 660.jpeg
# Procesada correctamente: 33.jpeg
# Procesada correctamente: 223.jpeg
# Procesada correctamente: 352.jpeg
# Procesada correctamente: 278.jpeg
# Procesada correctamente: 96.jpeg
# Procesada correctamente: 751.jpeg
# Procesada correctamente: 105.png
# Procesada correctamente: 965.jpeg
# Procesada correctamente: 369.jpeg
# Procesada correctamente: 841.jpeg
# Procesada correctamente: 289.jpeg
# Procesada correctamente: 569.png
# Procesada correctamente: 647.jpeg
# Procesada correctamente: 491.jpeg
# Procesada correctamente: 532.jpeg
# Procesada correctamente: 681.jpeg
# Procesada correctamente: 958.jpeg
# Procesada correctamente: 905.jpeg
# Procesada correctamente: 869.jpeg
# Procesada correctamente: 682.jpeg
# Procesada correctamente: 15.png
# Procesada correctamente: 124.jpeg
# Procesada correctamente: 213.jpeg
# Procesada correctamente: 789.png
# Procesada correctamente: 386.jpeg
# Procesada correctamente: 817.jpeg
# Procesada correctamente: 231.jpeg
# Procesada correctamente: 117.png
# Procesada correctamente: 610.jpeg
# Procesada correctamente: 508.jpeg
# Procesada correctamente: 131.jpeg
# Procesada correctamente: 893.jpeg
# Procesada correctamente: 295.jpeg
# Procesada correctamente: 86.jpeg
# Procesada correctamente: 217.jpeg
# Procesada correctamente: 849.jpeg
# Procesada correctamente: 911.jpeg
# Procesada correctamente: 460.png
# Procesada correctamente: 62.jpeg
# Procesada correctamente: 859.jpeg
# Procesada correctamente: 659.jpeg
# Procesada correctamente: 614.jpeg
# Procesada correctamente: 282.jpeg
# Procesada correctamente: 200.jpeg
# Procesada correctamente: 605.jpeg
# Procesada correctamente: 694.jpeg
# Procesada correctamente: 892.jpeg
# Procesada correctamente: 60.jpeg
# Procesada correctamente: 764.jpeg
# Procesada correctamente: 879.png
# Procesada correctamente: 966.jpeg
# Procesada correctamente: 740.jpeg
# Procesada correctamente: 394.png
# Procesada correctamente: 710.jpeg
# Procesada correctamente: 497.jpeg
# Procesada correctamente: 334.jpeg
# Procesada correctamente: 185.jpeg
# Procesada correctamente: 937.jpeg
# Procesada correctamente: 786.jpeg
# Procesada correctamente: 271.jpeg
# Procesada correctamente: 122.jpeg
# Procesada correctamente: 454.jpeg
# Procesada correctamente: 224.jpeg
# Procesada correctamente: 707.jpeg
# Procesada correctamente: 384.jpeg
# Procesada correctamente: 61.png
# Procesada correctamente: 89.jpeg
# Procesada correctamente: 312.jpeg
# Procesada correctamente: 552.jpeg
# Procesada correctamente: 507.jpeg
# Procesada correctamente: 36.jpeg
# Procesada correctamente: 346.jpeg
# Procesada correctamente: 76.jpeg
# Procesada correctamente: 884.jpeg
# Procesada correctamente: 527.jpeg
# Procesada correctamente: 307.jpeg
# Procesada correctamente: 831.jpeg
# Procesada correctamente: 533.jpeg
# Procesada correctamente: 590.jpeg
# Procesada correctamente: 58.jpeg
# Procesada correctamente: 540.jpeg
# Procesada correctamente: 465.jpeg
# Procesada correctamente: 946.jpeg
# Procesada correctamente: 536.jpeg
# Procesada correctamente: 974.jpeg
# Procesada correctamente: 990.png
# Procesada correctamente: 360.jpeg
# Procesada correctamente: 193.jpeg
# Procesada correctamente: 281.jpeg
# Procesada correctamente: 143.jpeg
# Procesada correctamente: 294.png
# Procesada correctamente: 780.jpeg
# Procesada correctamente: 583.jpeg
# Procesada correctamente: 480.jpeg
# Procesada correctamente: 736.jpeg
# Procesada correctamente: 708.jpeg
# Procesada correctamente: 215.jpeg
# Procesada correctamente: 549.jpeg
# Procesada correctamente: 579.jpeg
# Procesada correctamente: 133.jpeg
# Procesada correctamente: 557.png
# Procesada correctamente: 573.jpeg
# Procesada correctamente: 186.jpeg
# Procesada correctamente: 528.jpeg
# Procesada correctamente: 858.png
# Procesada correctamente: 474.jpeg
# Procesada correctamente: 487.jpeg
# Procesada correctamente: 91.jpeg
# Procesada correctamente: 414.jpeg
# Procesada correctamente: 568.jpeg
# Procesada correctamente: 27.jpeg
# Procesada correctamente: 80.jpeg
# Procesada correctamente: 867.png

# %%
df['ID'] = df['ID'].astype(int)
df = df.sort_values(by="ID").reset_index(drop=True)

# %%
df
# Out:
#       ID                                            caption
# 0      1                  a man in a car with a quote on it
# 1      2        a dog with long blonde hair and a fake face
# 2      3            a man in a white robe with his hands up
# 3      4  mes de mes memes memes memes memes memes memes...
# 4      5           a small dog with a big smile on its face
# ..   ...                                                ...
# 994  995  a picture of a soccer team with the capt that ...
# 995  996                a man is dancing in the living room
# 996  997          a baby in a hospital bed with a white hat
# 997  998             a cartoon picture of a group of people
# 998  999  a man with a black shirt and a black shirt wit...
#
# [999 rows x 2 columns]

# %%
df.to_csv('blip-imagecaptioning.csv',index=False)

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# Collecting googletrans==4.0.0-rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==4.0.0-rc1)
#   Downloading httpx-0.13.3-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.8.30)
# Collecting hstspreload (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hstspreload-2024.12.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting idna==2.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading httpcore-0.9.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h11-0.9.0-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h2-3.2.0-py2.py3-none-any.whl.metadata (32 kB)
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl.metadata (7.2 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 4.3 MB/s eta 0:00:00
# Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 8.8 MB/s eta 0:00:00
# Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.2 MB/s eta 0:00:00
# Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.1 MB/s eta 0:00:00
# Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 6.0 MB/s eta 0:00:00
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Downloading hstspreload-2024.12.1-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 45.0 MB/s eta 0:00:00
# Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.8 MB/s eta 0:00:00
# Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17397 sha256=748b48cad901ea4ac964a329d969ff18f1ac83f6bbc970b63bf89e4ae5d49d2c
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.7
#     Uninstalling httpcore-1.0.7:
#       Successfully uninstalled httpcore-1.0.7
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.2
#     Uninstalling httpx-0.27.2:
#       Successfully uninstalled httpx-0.27.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langsmith 0.1.143 requires httpx<1,>=0.23.0, but you have httpx 0.13.3 which is incompatible.
# openai 1.54.4 requires httpx<1,>=0.23.0, but you have httpx 0.13.3 which is incompatible.
# Successfully installed chardet-3.0.4 googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.12.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0

# %%
df = pd.read_csv('blip-imagecaptioning.csv')

# %%
from googletrans import Translator

# Instanciar el traductor
translator = Translator()

# Función para traducir texto al español con manejo de errores
def translate_to_spanish(text):
    try:
        if text:  # Verificar que el texto no sea None o vacío
            translation = translator.translate(text, src='en', dest='es')
            return translation.text
        else:
            return ""  # Si el texto es None o vacío, devolver una cadena vacía
    except Exception as e:
        print(f"Error al traducir el texto: {text}. Error: {e}")
        return text  # Devolver el texto original si ocurre un error

# Traducir las captions al español directamente desde el DataFrame
df['caption_spanish'] = df['caption'].apply(translate_to_spanish)
# Out:
# Error al traducir el texto: a picture of a soccer player with the words, que peo. Error: 'NoneType' object is not iterable
# Error al traducir el texto: a hamy with the words, ' i ams sio '. Error: 'NoneType' object is not iterable
# Error al traducir el texto: a baby is crying. Error: 'NoneType' object is not iterable
# Error al traducir el texto: a red ball with a face and a capt that reads, ` ' ' ' ' ' '. Error: 'NoneType' object is not iterable
# Error al traducir el texto: a crying smiley face with tears. Error: The read operation timed out
# Error al traducir el texto: a screenshot of a baby in a sling. Error: 'NoneType' object is not iterable
# Error al traducir el texto: a rada rada rada rada rada rada rada rada rada. Error: 'NoneType' object is not iterable
# Error al traducir el texto: a green apple with a smiley face on it. Error: 'NoneType' object is not iterable
# Error al traducir el texto: a poster with a picture of two graduates. Error: 'NoneType' object is not iterable
# Error al traducir el texto: a baby laying in bed with the capt that says, ` ` ` ` ` ` ` `. Error: 'NoneType' object is not iterable
# Error al traducir el texto: a cat with a vegem on it ' s face. Error: 'NoneType' object is not iterable
# Error al traducir el texto: a rad rad rad rad rad rad rad rad rad. Error: 'NoneType' object is not iterable
# Error al traducir el texto: cartoon of a dog and a doctor. Error: 'NoneType' object is not iterable
# Error al traducir el texto: a dog with a capt that says no live can. Error: 'NoneType' object is not iterable
# Error al traducir el texto: a dog with a magni on its head. Error: 'NoneType' object is not iterable
# Error al traducir el texto: a batman with the capt that says, ` ` ' ' ' ' ' ' ' ' '. Error: 'NoneType' object is not iterable
# Error al traducir el texto: a rad rad rad rad rad rad rad rad rad. Error: 'NoneType' object is not iterable
# Error al traducir el texto: a baby is sleeping on the floor with a hoodie. Error: 'NoneType' object is not iterable
# Error al traducir el texto: a cartoon character with a yellow hair and a black shirt. Error: The read operation timed out
# Error al traducir el texto: a cow with a capt that says, ' what ' s the cow? '. Error: The read operation timed out
# Error al traducir el texto: a baby in a hospital bed with a white hat. Error: 'NoneType' object is not iterable

# %%
df_new = df.drop(columns=['caption'])

# %%
df_new.rename(columns={'caption_spanish': 'caption'}, inplace=True)

# %%
df_new.to_csv('blip-imagecaptioning_complete.csv',index=False,encoding='utf-8-sig')
